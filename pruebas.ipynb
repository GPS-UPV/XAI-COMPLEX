# %%
import dtale
import dtale.global_state as global_state
import pandas as pd
 
global_state.set_app_settings(dict(enable_custom_filters=True))
global_state.set_chart_settings({"scatter_points": 150000, "3d_points": 400000})

# %%
df = pd.read_csv("./graphs/complexity_scores.csv")

# %%
d = dtale.show(df, notebook=True)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Laptop_1C:40000/dtale/iframe/8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
